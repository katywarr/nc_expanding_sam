# %% [markdown]
# # 2 - Run Optimising Sub-pattern Recognition: Memory Capacity (Generates Data for Figures 9 and 10)
#
#
# This notebook re-generates data for the section *Section 9.1: Optimising Sub-pattern Recognition* and caches it.
#
# **To just plot the results:**
# If you would like to just plot the pre-generated paper results, there is no need to re-generate the results as they are cached in `examples/experimental_results/experiment_A_sub_pattern`. In this case, simply use the Jupyter notebook `3 - Experiment_A_sub_pattern - Plot Figs 9 and 10.ipynb`.
#
# **Where the data will be saved:** The results from this test willl be saved in the existing Excel files in the `examples/experimental_results/experiment_A_sub_pattern` folder and overwrite the sheet named `latest_data`. The data generated for the paper is on the `paper_data` sheet, which will not be overwritten. You can select the data to plot (the latest or the paper data) by selecting the correct sheet name in `3 - Experiment_A_sub_pattern - Plot Figs 9 and 10.ipynb`.
#
# This notebook explores the effect on the sub-pattern recognition step through the two optimisation techniques:
#
# * Optimising the hidden neuron threshold
# * Optimising the feature to hidden neuron connections
#
# To examine the effect of the sub-pattern recognition optimisations on ESAM network memory capacity, the following experiment is used:
#
# <table>
# <tr><td>
#
# | Problem A    |          |
# | :----------- | :------  |
# | $f$          | 900      |
# | $m$          | 0 - 25,000 |
# | $s_m$        | 0.22     |
# | $s_n$        | 0        |
# </td><td>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
# </td><td>
#
# | Network A (Baseline) |          |
# | :--------------------| :------  |
# | $h$                  | 2        |
# | $\theta$             | 12       |
# | $s^+_{f\_h}$         | 0.1      |
# | $\sigma_{h\_pre+}$   | `FixedProbability` |
# | $s^+_{h\_f}$         | 1     |
# | $s^-_{h\_f}$         | 1     |
# | $\sigma_{f\_pre+}$, $\sigma_{f\_pre-}$  |  `FixedProbability`       |
# | $e$                  | 3        |
#
# </td></tr> </table>
#
# Note that this is a very simple verification of `f(x)=x` as there is no noise present in the recall signals. It is based on the baseline experiment presented in [1] (figure 4a).
#
# The accuracy of four different networks are compared in the graphs as the number of memories $m$ varies:
#
# * Network A - the baseline network from [1] (as described above).
# * Network A with $\theta$ optimised for each test as described in section 6.2.
# * Network A with sub-pattern recognition (feature to hidden) connections optimised as described in section 6.3.
# * Network A with $\theta$ and the connections optimised
#
# The accuracy of each network is tested with increasing numbers of memories. This is the only variable that changes during the tests.
#
#
#
# [1] Hoffmann, H. (2019). Sparse Associative Memory. *Neural Computation*

# %% [markdown]
# ## Dependencies and problem/network definition
#
# Import the dependencies and define the tests to run.

# %% [markdown]
# ### Dependencies

# %%
import os
import sys
sys.path.append('../src')

# %%
output_base_dir = '.'+os.sep+'experiment_results'
test_name = 'experiment_A_sub_pattern'

# %% [markdown]
# ### Define the problem space and base network
#
# Provide the default values for the problem space and the network. The tests will be variations
# on these defaults.

# %%
f = 900
s_m = 200/f
problem_space_default = {'f': f,
                         'm': 200,
                         's_m': s_m,
                         's_n': 0}

network_default = {'f': f,
                   'h': 2,
                   'f_h_sparsity': 0.1,
                   'h_f_sparsity_e': 1,
                   'h_f_sparsity_i': 1,
                   'e': 3,
                   'h_thresh': 12,
                   'f_h_conn_type': 'FixedProbability',
                   'h_f_conn_type': 'FixedProbability',
                   'debug': False
                   }

# %% [markdown]
# ### Define the variable that will change (the x-axis on the final plots)
#
# In this case, the variable that is changed is the number of memories `m`.

# %%
# Below is the full test, as in the paper.
vary_memories = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 5000, 10000, 15000, 20000]

# The full test will take a long time to run. You can experiment with fewer memories.
# You can also reduce the number of simulations that are run per memory variation - see the 
# 'Run the Tests' section below. 
vary_memories = [100, 200, 300]

# %% [markdown]
# ### Define the networks to be tested.
#
# Each network will be tested multiple times for each of the variable options.
#
# The `problem_vary` and `network_static` dictionary keys indicate that the variation betweeen the tests (for each network) is the problem space - specifically in this case, the number of memories `m`
#
# There are 4 network varieties:
# * `original`: the original network from the paper.
# * `opt_thresh`: the original network with the hidden neuron threshold optimised for each of the varying memory scenarios.
# * `opt_conns`: the original network with the feature to hidden (sub-pattern) connections optimised.
# * `opt_thresh_conns`: the original network combining the optimisations of both `opt_thresh` and `opt_conns`.

# %%
import copy

original={
            'problem_vary': problem_space_default.copy(),
            'network_static': network_default.copy(),
            'plot_params':
                {'variable_column': 'm',
                 'variable_column_name': 'Number of memories',
                 'variable_is_integer': False}
         }


# Override with the variable parameter. Specifying an array for this parameter will
# indicate to the test runner that there are multiple scenarios to be tested.
original['problem_vary'][original['plot_params']['variable_column']] = vary_memories

opt_thresh = copy.deepcopy(original)
opt_thresh['network_static']['h_thresh'] = -1     # -1 means optimise the threshold

opt_conns = copy.deepcopy(original)
opt_conns['network_static']['f_h_conn_type'] = 'FixedNumberPre'

opt_thresh_conns = copy.deepcopy(opt_thresh)
opt_thresh_conns['network_static']['f_h_conn_type'] = 'FixedNumberPre'

# %% [markdown]
# Put all the network descriptions into a single dictionary for the test runner.

# %%
all_tests = {'original': original,
             'opt_thresh': opt_thresh,
             'opt_conns': opt_conns,
             'opt_thresh_conns': opt_thresh_conns
            }

# %% [markdown]
# ## Run the tests
#
# `num_tests` is the number of networks for each type of test that will be created. Despite having the same network definition, each will vary due to randomness in the data and network connections.
#
# `simulations_per_test` is the number of recalls that will be run on each test network.
#
# The total number of tests that will be run is: `number of test networks (4) * len(vary_m) * num_tests * simulations_per_test`
#
# This test is classified as `vary_problem` because the network remains static for each optimisation test, but the problem is varied.

# %%
num_tests = 10
sims_per_test = 10
output_dir = output_base_dir + os.sep + test_name

# %%
from simulation_scripts.test_suite_runner import TestSuiteRunner

tsr = TestSuiteRunner(network_default=network_default,
                      problem_space_default=problem_space_default,
                      output_dir=output_dir)


tsr.run_vary_problem_space_test_suite(all_tests = all_tests,
                                      num_tests = num_tests,
                                      sims_per_test = sims_per_test)
# Out:
# ================================================================================================
# Running test set: original defined as:
#     Static network params:    {'f': 900, 'h': 2, 'f_h_sparsity': 0.1, 'h_f_sparsity_e': 1, 'h_f_sparsity_i': 1, 'e': 3, 'h_thresh': 12, 'f_h_conn_type': 'FixedProbability', 'h_f_conn_type': 'FixedProbability', 'debug': False}
#     Varying problem space:    {'f': 900, 'm': [100, 200, 300], 's_m': 0.2222222222222222, 's_n': 0}
#
# Number of tests per scenario: 10
# Number of simulations per test: 10
#
# --------------------------------------------------------------------------------------------
# Simulation 1 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.06ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.37
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 2 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.22
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 3 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 100 memories
# 100 memories learnt in 0.0s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.28
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 4 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.27
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 5 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.3
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 6 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.21
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 7 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.24
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 8 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.29
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 9 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 100 memories
# 100 memories learnt in 0.0s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.24
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 10 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 100 memories
# 100 memories learnt in 0.0s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.33
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 1 of 10 for test 2 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   200
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 200 memories
# 200 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  4.37
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 2 of 10 for test 2 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   200
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 200 memories
# 200 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  4.43
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 3 of 10 for test 2 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   200
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 200 memories
# 200 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  4.49
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 4 of 10 for test 2 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   200
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 200 memories
# 200 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  4.38
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 5 of 10 for test 2 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   200
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 200 memories
# 200 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  4.44
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 6 of 10 for test 2 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   200
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 200 memories
# 200 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  4.48
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 7 of 10 for test 2 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   200
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 200 memories
# 200 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  4.41
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 8 of 10 for test 2 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   200
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 200 memories
# 200 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  4.46
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 9 of 10 for test 2 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   200
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 200 memories
# 200 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  4.44
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 10 of 10 for test 2 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   200
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 200 memories
# 200 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  4.51
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 1 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 300 memories
# 300 memories learnt in 0.02s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.65
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 2 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 300 memories
# 300 memories learnt in 0.02s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.95
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 3 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 300 memories
# 300 memories learnt in 0.02s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.54
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 4 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 300 memories
# 300 memories learnt in 0.02s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.73
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 5 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 300 memories
# 300 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.56
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 6 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 300 memories
# 300 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.99
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 7 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 300 memories
# 300 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.5
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 8 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 300 memories
# 300 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.78
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 9 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 300 memories
# 300 memories learnt in 0.02s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.63
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 10 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               12
#
# >> Learning 300 memories
# 300 memories learnt in 0.02s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.91
# Simulation complete
# Writing full simulation data for tests to file: ./experiment_results/experiment_A_sub_pattern/original.xlsx
# ... Writing test description sheets (will override previous)
# ... Writing test results to sheets: 2025-02-11-14-40 and latest
# Running test set: original COMPLETE
#
# ================================================================================================
# Running test set: opt_thresh defined as:
#     Static network params:    {'f': 900, 'h': 2, 'f_h_sparsity': 0.1, 'h_f_sparsity_e': 1, 'h_f_sparsity_i': 1, 'e': 3, 'h_thresh': -1, 'f_h_conn_type': 'FixedProbability', 'h_f_conn_type': 'FixedProbability', 'debug': False}
#     Varying problem space:    {'f': 900, 'm': [100, 200, 300], 's_m': 0.2222222222222222, 's_n': 0}
#
# Number of tests per scenario: 10
# Number of simulations per test: 10
#
# --------------------------------------------------------------------------------------------
# Simulation 1 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedProbability
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            100
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  14
#     The recommended hidden neuron threshold is 14
#     Using probability of f-h connections per hidden neuron: 0.1 gives an average of : 20 connections
#
# Using generated threshold: 14
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               14
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.37
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 2 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedProbability
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            100
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  14
#     The recommended hidden neuron threshold is 14
#     Using probability of f-h connections per hidden neuron: 0.1 gives an average of : 20 connections
#
# Using generated threshold: 14
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               14
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.27
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 3 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedProbability
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            100
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  14
#     The recommended hidden neuron threshold is 14
#     Using probability of f-h connections per hidden neuron: 0.1 gives an average of : 20 connections
#
# Using generated threshold: 14
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               14
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.24
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 4 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedProbability
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            100
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  14
#     The recommended hidden neuron threshold is 14
#     Using probability of f-h connections per hidden neuron: 0.1 gives an average of : 20 connections
#
# Using generated threshold: 14
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               14
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.24
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 5 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedProbability
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            100
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  14
#     The recommended hidden neuron threshold is 14
#     Using probability of f-h connections per hidden neuron: 0.1 gives an average of : 20 connections
#
# Using generated threshold: 14
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               14
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.25
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 6 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedProbability
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            100
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  14
#     The recommended hidden neuron threshold is 14
#     Using probability of f-h connections per hidden neuron: 0.1 gives an average of : 20 connections
#
# Using generated threshold: 14
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               14
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.27
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 7 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedProbability
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            100
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  14
#     The recommended hidden neuron threshold is 14
#     Using probability of f-h connections per hidden neuron: 0.1 gives an average of : 20 connections
#
# Using generated threshold: 14
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               14
#
# >> Learning 100 memories
# 100 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.23
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 8 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedProbability
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            100
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  14
#     The recommended hidden neuron threshold is 14
#     Using probability of f-h connections per hidden neuron: 0.1 gives an average of : 20 connections
#
# Using generated threshold: 14
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedProbability
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               14
#
# >> Learning 100 memories
# 100 memories learnt in 0.0s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  2.32
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 9 of 10 for test 1 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   100
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# ...
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedNumberPre
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            300
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  17
#     The recommended hidden neuron threshold is 17
#     Using static f-h connections proportion: 0.1 gives exactly 20 connections per hidden neuron.
# Using generated threshold: 17
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedNumberPre
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               17
#
# >> Learning 300 memories
# 300 memories learnt in 0.01s. Approx time per memory: 0.04ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.64
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 3 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedNumberPre
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            300
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  17
#     The recommended hidden neuron threshold is 17
#     Using static f-h connections proportion: 0.1 gives exactly 20 connections per hidden neuron.
# Using generated threshold: 17
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedNumberPre
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               17
#
# >> Learning 300 memories
# 300 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.74
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 4 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedNumberPre
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            300
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  17
#     The recommended hidden neuron threshold is 17
#     Using static f-h connections proportion: 0.1 gives exactly 20 connections per hidden neuron.
# Using generated threshold: 17
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedNumberPre
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               17
#
# >> Learning 300 memories
# 300 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.42
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 5 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedNumberPre
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            300
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  17
#     The recommended hidden neuron threshold is 17
#     Using static f-h connections proportion: 0.1 gives exactly 20 connections per hidden neuron.
# Using generated threshold: 17
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedNumberPre
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               17
#
# >> Learning 300 memories
# 300 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.38
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 6 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedNumberPre
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            300
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  17
#     The recommended hidden neuron threshold is 17
#     Using static f-h connections proportion: 0.1 gives exactly 20 connections per hidden neuron.
# Using generated threshold: 17
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedNumberPre
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               17
#
# >> Learning 300 memories
# 300 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.44
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 7 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedNumberPre
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            300
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  17
#     The recommended hidden neuron threshold is 17
#     Using static f-h connections proportion: 0.1 gives exactly 20 connections per hidden neuron.
# Using generated threshold: 17
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedNumberPre
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               17
#
# >> Learning 300 memories
# 300 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.58
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 8 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedNumberPre
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            300
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  17
#     The recommended hidden neuron threshold is 17
#     Using static f-h connections proportion: 0.1 gives exactly 20 connections per hidden neuron.
# Using generated threshold: 17
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedNumberPre
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               17
#
# >> Learning 300 memories
# 300 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.53
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 9 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedNumberPre
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            300
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  17
#     The recommended hidden neuron threshold is 17
#     Using static f-h connections proportion: 0.1 gives exactly 20 connections per hidden neuron.
# Using generated threshold: 17
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedNumberPre
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               17
#
# >> Learning 300 memories
# 300 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.43
# Simulation complete
#
# --------------------------------------------------------------------------------------------
# Simulation 10 of 10 for test 3 of 3
#
# ======= Generating Simulation Data =======
#       Number of features (feature neurons): 900
#       Number of memories:                   300
#       Number of simulations:                10
#       Signal length:                        200
#       Bits to flip for noise:               0
# Establishing hidden neuron threshold for the following test:
#     net_param_f:             900
#     net_param_h:             2
#     net_param_f_h_sparsity:  0.1
#     net_param_f_h_conn_type: FixedNumberPre
#     data_param_s_m:          0.2222222222222222
#     data_param_s_n:          0
#     data_param_m:            300
#     Checking for previously cached probability results in file ../hyperparameter_data/hidden_neuron_activations.xlsx
#     Using cached probability data from ../hyperparameter_data/hidden_neuron_activations.xlsx
# Recommended Threshold Accuracy inhib:  17
#     The recommended hidden neuron threshold is 17
#     Using static f-h connections proportion: 0.1 gives exactly 20 connections per hidden neuron.
# Using generated threshold: 17
#
#   Learning phase...
#
# =========== ESAM Recall Network =============
#     Num features:                   900
#     F to H connection sparsity:     0.1
#       Static F to H conn type?      FixedNumberPre
#     H to F exitatory sparsity:      1
#     H to F inhibitory sparsity:     1
#       Static H to F conn type?      FixedProbability
#     Max epochs per recall:          3
#     Hidden per memory:              2
#     Hidden threshold:               17
#
# >> Learning 300 memories
# 300 memories learnt in 0.01s. Approx time per memory: 0.05ms
#   Recall phase...
#
# >> Recalling 10 tests.
# Recall complete. Average time per test (ms) was:  6.56
# Simulation complete
# Writing full simulation data for tests to file: ./experiment_results/experiment_A_sub_pattern/opt_thresh_conns.xlsx
# ... Writing test description sheets (will override previous)
# ... Writing test results to sheets: 2025-02-11-14-40 and latest
# Running test set: opt_thresh_conns COMPLETE

# %%
print('Experiment complete, data stored in:\n')
print('  {:80s}    {:10s}\n'.format('File', 'Sheet'))

for test_file, _ in all_tests.items():
    excel_file = output_base_dir + os.sep + test_name + os.sep + test_file + '.xlsx'
    print('  {:80s}    {:10s}'.format(excel_file, 'latest'))
# Out:
# Experiment complete, data stored in:
#
#   File                                                                                Sheet
#
#   ./experiment_results/experiment_A_sub_pattern/original.xlsx                         latest
#   ./experiment_results/experiment_A_sub_pattern/opt_thresh.xlsx                       latest
#   ./experiment_results/experiment_A_sub_pattern/opt_conns.xlsx                        latest
#   ./experiment_results/experiment_A_sub_pattern/opt_thresh_conns.xlsx                 latest

# %% [markdown]
# ## Next steps: Plotting the results
#
# Use the Jupyter notebook `3 - Experiment_A_sub_pattern - Plot Figs 9 and 10.ipynb` to plot the results.
#
# You will need to update the `data_sheet` variable to `latest_data` as described in the notebook, else the pre-generated paper data will be plotted.
